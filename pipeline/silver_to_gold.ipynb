# %% [markdown]
# # Pipeline Silver to Gold - One Big Table (OBT)
# ## Criação de tabelas desnormalizadas para análises avançadas

# %% [markdown]
# ## Validando a SparkSession

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="/?o=1083472119584360#setting/sparkui/0616-222516-xr2yuvm9/driver-1410770646845699042">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.3.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[8]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Databricks Shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ## Configurações iniciais - Azure ADLS Gen2

# %%
storageAccountName = "datalake7eadf73a479de9f7"
sasToken = "sv=2024-11-04&ss=bfqt&srt=sco&sp=rwdlacupyx&se=2025-06-17T06:41:14Z&st=2025-06-16T22:41:14Z&spr=https&sig=Uf2WLDhVdGJ04gP2VO2OffNHE0SKBqV%2B7twWqdpIxqc%3D"

def mount_adls(blobContainerName):
    mount_point = f"/mnt/{storageAccountName}/{blobContainerName}"
    
    # Verificar se já está montado
    existing_mounts = [mount.mountPoint for mount in dbutils.fs.mounts()]
    
    if mount_point in existing_mounts:
        print(f"AVISO: {mount_point} já está montado. Desmontando primeiro...")
        try:
            dbutils.fs.unmount(mount_point)
            print(f"Desmontado com sucesso: {mount_point}")
        except Exception as e:
            print(f"Erro ao desmontar {mount_point}: {e}")
            return False
    
    # Montar o container
    try:
        dbutils.fs.mount(
            source = "wasbs://{}@{}.blob.core.windows.net".format(blobContainerName, storageAccountName),
            mount_point = mount_point,
            extra_configs = {'fs.azure.sas.' + blobContainerName + '.' + storageAccountName + '.blob.core.windows.net': sasToken}
        )
        print(f"Container {blobContainerName} montado com sucesso!")
        return True
    except Exception as e:
        print(f"Falha ao montar {blobContainerName}: {e}")
        return False

# %% [markdown]
# ### Função para verificar se ambiente já está montado

# %%
def mount_adls_safe(blobContainerName):
    mount_point = f"/mnt/{storageAccountName}/{blobContainerName}"
    existing_mounts = [mount.mountPoint for mount in dbutils.fs.mounts()]
    
    if mount_point in existing_mounts:
        print(f"OK! {mount_point} já está montado.")
        return True
    else:
        return mount_adls(blobContainerName)

# %% [markdown]
# ## Montando containers necessários

# %%
mount_adls('gold')
# Out:
# AVISO: /mnt/datalake7eadf73a479de9f7/gold já está montado. Desmontando primeiro...
# /mnt/datalake7eadf73a479de9f7/gold has been unmounted.
# Desmontado com sucesso: /mnt/datalake7eadf73a479de9f7/gold
# Container gold montado com sucesso!
# Out[86]: True

# %% [markdown]
# ### Limpar container da camada Gold

# %%
def clean_gold_container():
    gold_path = f"/mnt/{storageAccountName}/gold"
    
    try:
        # Verificar se o path existe
        try:
            files_and_dirs = dbutils.fs.ls(gold_path)
        except Exception:
            print(f"Path {gold_path} não existe ou está vazio.")
            return True
        
        if not files_and_dirs:
            print("Container gold já está vazio.")
            return True
        
        print(f"Encontrados {len(files_and_dirs)} itens no gold para exclusão...")
        
        # Excluir cada item (arquivos e diretórios)
        for item in files_and_dirs:
            try:
                dbutils.fs.rm(item.path, True)  # True para recursivo
                print(f"✓ Excluído: {item.name}")
            except Exception as e:
                print(f"✗ Erro ao excluir {item.name}: {str(e)}")
                return False
        
        print("✅ Limpeza do container gold concluída com sucesso!")
        return True
        
    except Exception as e:
        print(f"❌ Erro geral na limpeza do gold: {str(e)}")
        return False

# %% [markdown]
# ## Importando bibliotecas necessárias

# %%
from pyspark.sql.functions import (
    current_timestamp, lit, col, when, isnan, isnull, 
    count, sum as spark_sum, avg, max as spark_max, min as spark_min,
    concat_ws, coalesce, date_format, year, month, dayofmonth,
    dense_rank, row_number, round as spark_round, collect_set,
    current_date, datediff, count_distinct as countDistinct,
    first, last, stddev, variance, split, size, array_contains
)
from pyspark.sql.window import Window
from pyspark.sql.types import *

# %% [markdown]
# ### Definindo nome da database e criando camada gold

# %%
# Definindo configurações da camada Gold
database_name = "pipeline_silver"

def salvar_obt_gold(df, table_name):
    """Salva DataFrame na camada Gold - tanto como tabela quanto no Data Lake"""
    try:
        # Criar database se não existir
        spark.sql("CREATE DATABASE IF NOT EXISTS pipeline_gold")
        
        # Caminho no Data Lake Gold
        gold_path = f"/mnt/{storageAccountName}/gold/{table_name}"
        
        # Salvar no Data Lake como Delta (formato recomendado)
        print(f"💾 Salvando {table_name} no Data Lake Gold...")
        df.write \
          .format("delta") \
          .mode("overwrite") \
          .option("overwriteSchema", "true") \
          .save(gold_path)
        
        # Registrar como tabela externa no catálogo
        print(f"📋 Registrando tabela {table_name} no catálogo...")
        spark.sql(f"""
            CREATE TABLE IF NOT EXISTS pipeline_gold.{table_name}
            USING DELTA
            LOCATION '{gold_path}'
        """)
        
        # Otimizar tabela Delta
        spark.sql(f"OPTIMIZE pipeline_gold.{table_name}")
        
        print(f"✅ Tabela {table_name} salva com sucesso!")
        print(f"   📊 Registros: {df.count():,}")
        print(f"   📁 Localização: {gold_path}")
        print(f"   🏷️ Tabela: pipeline_gold.{table_name}")
        
    except Exception as e:
        print(f"❌ Erro ao salvar tabela {table_name}: {str(e)}")

# %% [markdown]
# ## Verificando tabelas disponíveis na camada Silver

# %%
# Verificar se existem tabelas
tabelas_disponiveis = spark.sql(f"SHOW TABLES IN {database_name}").collect()
if not tabelas_disponiveis:
    print(f"Nenhuma tabela encontrada em {database_name}")

# %% [markdown]
# ## Carregando dados das tabelas Silver

# %%
def carregar_tabelas_silver():
    """Carrega todas as tabelas da camada Silver"""
    
    tabelas = {}
    
    try:
        tabelas_disponiveis = spark.sql(f"SHOW TABLES IN {database_name}").collect()
        
        if not tabelas_disponiveis:
            print(f"❌ Nenhuma tabela encontrada em {database_name}")
            return tabelas
        
        print(f"📊 Carregando {len(tabelas_disponiveis)} tabelas da camada Silver...")
        
        for tabela in tabelas_disponiveis:
            nome_tabela = tabela['tableName']
            df = spark.sql(f"SELECT * FROM {database_name}.{nome_tabela}")
            tabelas[nome_tabela] = df
            
    except Exception as e:
        print(f"❌ Erro ao carregar tabelas: {str(e)}")
    
    return tabelas

silver_tables = carregar_tabelas_silver()
# Out:
# 📊 Carregando 14 tabelas da camada Silver...

# %% [markdown]
# ### Executando a função para carregar

# %%
silver_tables = carregar_tabelas_silver()
# Out:
# 📊 Carregando 14 tabelas da camada Silver...

# %% [markdown]
# ## Função para criar e salvar OBT na camada Gold

# %%
def criar_one_big_table(silver_tables):
    """
    Cria uma única One Big Table integrando todas as informações necessárias
    """
    
    try:
        print("🏗️  Construindo One Big Table única...")
        
        # === VERIFICAÇÃO INICIAL ===
        if not silver_tables:
            print("❌ Nenhuma tabela encontrada!")
            return None
        
        print(f"📋 Tabelas disponíveis: {list(silver_tables.keys())}")
        
        # Tabela principal obrigatória
        games = silver_tables.get('games')
        if games is None:
            print("❌ Tabela 'games' é obrigatória!")
            return None
        
        print(f"✅ Tabela 'games' com {games.count()} registros")
        print(f"📋 Colunas da tabela games: {games.columns}")
        
        # Tabelas auxiliares
        purchases = silver_tables.get('purchases')
        reviews = silver_tables.get('reviews')
        achievements = silver_tables.get('achievements')
        achievement_unlocked = silver_tables.get('achievement_unlocked')
        dlcs = silver_tables.get('dlcs')
        game_platforms = silver_tables.get('game_platforms')
        platforms = silver_tables.get('platforms')
        game_genders = silver_tables.get('game_genders')
        genders = silver_tables.get('genders')
        game_tags = silver_tables.get('game_tags')
        tags = silver_tables.get('tags')
        developers = silver_tables.get('developers')
        wishlist = silver_tables.get('wishlist')
        
        # === CRIANDO AGREGAÇÕES ===
        print("📊 Criando agregações...")
        
        # 1. Agregações de Vendas
        purchases_metrics = None
        if purchases is not None:
            try:
                purchases_metrics = purchases.groupBy("GAME_ID").agg(
                    count("*").alias("total_purchases"),
                    countDistinct("USER_ID").alias("unique_buyers") if "USER_ID" in purchases.columns else count("*").alias("unique_buyers"),
                    first("PURCHASE_DATE").alias("first_purchase_date") if "PURCHASE_DATE" in purchases.columns else lit(None).alias("first_purchase_date"),
                    spark_max("PURCHASE_DATE").alias("last_purchase_date") if "PURCHASE_DATE" in purchases.columns else lit(None).alias("last_purchase_date")
                )
                print("    ✅ Métricas de vendas processadas")
            except Exception as e:
                print(f"    ⚠️ Erro em purchases: {e}")
        
        # 2. Agregações de Avaliações
        reviews_metrics = None
        if reviews is not None:
            try:
                reviews_metrics = reviews.groupBy("GAME_ID").agg(
                    avg("RATING").alias("avg_rating"),
                    count("*").alias("total_reviews"),
                    spark_max("RATING").alias("max_rating"),
                    spark_min("RATING").alias("min_rating"),
                    stddev("RATING").alias("rating_stddev"),
                    count(when(col("RATING") >= 4, True)).alias("positive_reviews"),
                    count(when(col("RATING") <= 2, True)).alias("negative_reviews"),
                    countDistinct("USER_ID").alias("unique_reviewers") if "USER_ID" in reviews.columns else count("*").alias("unique_reviewers")
                )
                print("    ✅ Métricas de avaliações processadas")
            except Exception as e:
                print(f"    ⚠️ Erro em reviews: {e}")

        # 3. Agregações de Achievements
        achievements_metrics = None
        if achievements is not None:
            try:
                achievements_base = achievements.groupBy("GAME_ID").agg(
                    count("*").alias("total_achievements_available")
                )
                
                if achievement_unlocked is not None:
                    achievements_unlocked = (
                        achievement_unlocked
                        .join(achievements, col("achievement_unlocked.ACHIEVEMENT_ID") == col("achievements.ID"))
                        .groupBy("achievements.GAME_ID").agg(
                            count("*").alias("total_achievements_unlocked"),
                            countDistinct("achievement_unlocked.USER_ID").alias("users_with_achievements") if "USER_ID" in achievement_unlocked.columns else count("*").alias("users_with_achievements")
                        )
                    )
                    achievements_metrics = achievements_base.join(achievements_unlocked, "GAME_ID", "left")
                else:
                    achievements_metrics = achievements_base.withColumn("total_achievements_unlocked", lit(0)).withColumn("users_with_achievements", lit(0))
                
                print("    ✅ Métricas de achievements processadas")
            except Exception as e:
                print(f"    ⚠️ Erro em achievements: {e}")

        # 4. Agregações de DLCs
        dlcs_metrics = None
        base_game_col = None
        if dlcs is not None:
            try:
                for possible_col in ["BASEGAMEID", "BASE_GAME_ID", "GAME_ID"]:
                    if possible_col in dlcs.columns:
                        base_game_col = possible_col
                        break
                
                if base_game_col:
                    agg_list = [count("*").alias("total_dlcs")]
                    if "PRICE" in dlcs.columns:
                        agg_list.extend([
                            spark_sum("PRICE").alias("total_dlcs_value"),
                            avg("PRICE").alias("avg_dlc_price")
                        ])
                    
                    dlcs_metrics = dlcs.groupBy(base_game_col).agg(*agg_list)
                    print("    ✅ Métricas de DLCs processadas")
            except Exception as e:
                print(f"    ⚠️ Erro em dlcs: {e}")

        # 5. Agregações de Plataformas
        platforms_info = None
        if game_platforms is not None and platforms is not None:
            try:
                platforms_info = (
                    game_platforms
                    .join(platforms, col("game_platforms.PLATFORM_ID") == col("platforms.ID"))
                    .groupBy("game_platforms.GAME_ID").agg(
                        count("*").alias("total_platforms"),
                        concat_ws(", ", collect_set("platforms.NAME")).alias("platforms_list")
                    )
                )
                print("    ✅ Informações de plataformas processadas")
            except Exception as e:
                print(f"    ⚠️ Erro em platforms: {e}")

        # 6. Agregações de Gêneros
        genres_info = None
        if game_genders is not None and genders is not None:
            try:
                genres_info = (
                    game_genders
                    .join(genders, col("game_genders.GENDER_ID") == col("genders.ID"))
                    .groupBy("game_genders.GAME_ID").agg(
                        count("*").alias("total_genres"),
                        concat_ws(", ", collect_set("genders.NAME")).alias("genres_list")
                    )
                )
                print("    ✅ Informações de gêneros processadas")
            except Exception as e:
                print(f"    ⚠️ Erro em genres: {e}")

        # 7. Agregações de Tags
        tags_info = None
        if game_tags is not None and tags is not None:
            try:
                tags_info = (
                    game_tags
                    .join(tags, col("game_tags.TAG_ID") == col("tags.ID"))
                    .groupBy("game_tags.GAME_ID").agg(
                        count("*").alias("total_tags"),
                        concat_ws(", ", collect_set("tags.NAME")).alias("tags_list")
                    )
                )
                print("    ✅ Informações de tags processadas")
            except Exception as e:
                print(f"    ⚠️ Erro em tags: {e}")
        
        # 8. Agregações de Wishlist
        wishlist_metrics = None
        if wishlist is not None:
            try:
                wishlist_metrics = wishlist.groupBy("GAME_ID").agg(
                    count("*").alias("total_wishlisted"),
                    countDistinct("USER_ID").alias("unique_wishlisters")
                )
                print("    ✅ Métricas de wishlist processadas")
            except Exception as e:
                print(f"    ⚠️ Erro em wishlist: {e}")

        # === CONSTRUINDO A OBT ===
        print("🔧 Montando One Big Table...")
        
        obt = games
        
        if developers is not None:
            try:
                # Renomear colunas antes do join para evitar ambiguidade
                dev_renamed = developers.select(
                    col("ID").alias("dev_id"), 
                    col("NAME").alias("developer_name")
                )
                obt = obt.join(dev_renamed, obt.DEVELOPER_ID == dev_renamed.dev_id, "left")
                print("    ✅ Join com developers")
            except Exception as e:
                print(f"    ⚠️ Erro no join com developers: {e}")

        # Joins com todas as métricas
        joins_config = [
            (purchases_metrics, "purchases"),
            (reviews_metrics, "reviews"),
            (achievements_metrics, "achievements"),
            (dlcs_metrics, "dlcs"),
            (platforms_info, "platforms"),
            (genres_info, "genres"),
            (tags_info, "tags"),
            (wishlist_metrics, "wishlist")
        ]
        
        for metrics_df, name in joins_config:
            if metrics_df is not None:
                try:
                    # Define a chave de junção no dataframe de métricas
                    join_key = base_game_col if name == "dlcs" and base_game_col else "GAME_ID"

                    # Realiza o join de forma segura
                    obt = obt.join(metrics_df, obt.ID == metrics_df[join_key], "left").drop(metrics_df[join_key])
                    
                    print(f"    ✅ Join com {name}")
                except Exception as e:
                    print(f"    ⚠️ Erro no join com {name}: {e}")

        # === VERIFICAÇÃO DAS COLUNAS DISPONÍVEIS ===
        print("🔍 Verificando colunas disponíveis após joins...")
        available_columns = obt.columns
        print(f"📋 Total de colunas: {len(available_columns)}")
        
        # Função auxiliar para verificar se coluna existe
        def safe_col(col_name, default_value=None, alias_name=None):
            if col_name in available_columns:
                return col(col_name).alias(alias_name) if alias_name else col(col_name)
            else:
                return lit(default_value).alias(alias_name) if alias_name else lit(default_value)

        # === SELEÇÃO E TRANSFORMAÇÃO FINAL ===
        print("🎯 Criando colunas finais...")
        
        # Lista de colunas finais com verificação de existência
        final_columns = [
            # Informações básicas do jogo
            safe_col("ID", alias_name="game_id"),
            coalesce(safe_col("TITLE", ""), lit("")).alias("game_title"),
            coalesce(safe_col("DESCRIPTION", ""), lit("")).alias("game_description"),
            coalesce(safe_col("PRICE", 0.0), lit(0.0)).alias("game_price"),
            safe_col("RELEASE_DATE", alias_name="release_date"),
            coalesce(safe_col("IMAGE_PATH", ""), lit("")).alias("image_path"),
            
            # Informações do desenvolvedor
            coalesce(safe_col("developer_name", "Unknown"), lit("Unknown")).alias("developer_name"),
            
            # Métricas de vendas
            coalesce(safe_col("total_purchases", 0), lit(0)).alias("total_purchases"),
            coalesce(safe_col("unique_buyers", 0), lit(0)).alias("unique_buyers"),
            safe_col("first_purchase_date"),
            safe_col("last_purchase_date"),
            
            # Métricas de avaliação
            coalesce(safe_col("avg_rating", 0.0), lit(0.0)).alias("avg_rating"),
            coalesce(safe_col("total_reviews", 0), lit(0)).alias("total_reviews"),
            coalesce(safe_col("max_rating", 0), lit(0)).alias("max_rating"),
            coalesce(safe_col("min_rating", 0), lit(0)).alias("min_rating"),
            coalesce(safe_col("rating_stddev", 0.0), lit(0.0)).alias("rating_stddev"),
            coalesce(safe_col("positive_reviews", 0), lit(0)).alias("positive_reviews"),
            coalesce(safe_col("negative_reviews", 0), lit(0)).alias("negative_reviews"),
            coalesce(safe_col("unique_reviewers", 0), lit(0)).alias("unique_reviewers"),
            
            # Métricas de achievements
            coalesce(safe_col("total_achievements_available", 0), lit(0)).alias("total_achievements_available"),
            coalesce(safe_col("total_achievements_unlocked", 0), lit(0)).alias("total_achievements_unlocked"),
            coalesce(safe_col("users_with_achievements", 0), lit(0)).alias("users_with_achievements"),
            
            # Métricas de DLCs
            coalesce(safe_col("total_dlcs", 0), lit(0)).alias("total_dlcs"),
            coalesce(safe_col("total_dlcs_value", 0.0), lit(0.0)).alias("total_dlcs_value"),
            coalesce(safe_col("avg_dlc_price", 0.0), lit(0.0)).alias("avg_dlc_price"),
            
            # Informações de plataformas
            coalesce(safe_col("total_platforms", 0), lit(0)).alias("total_platforms"),
            coalesce(safe_col("platforms_list", ""), lit("")).alias("platforms_list"),
            
            # Informações de gêneros
            coalesce(safe_col("total_genres", 0), lit(0)).alias("total_genres"),
            coalesce(safe_col("genres_list", ""), lit("")).alias("genres_list"),
            
            # Informações de tags
            coalesce(safe_col("total_tags", 0), lit(0)).alias("total_tags"),
            coalesce(safe_col("tags_list", ""), lit("")).alias("tags_list"),
            
            # Métricas de wishlist
            coalesce(safe_col("total_wishlisted", 0), lit(0)).alias("total_wishlisted"),
            coalesce(safe_col("unique_wishlisters", 0), lit(0)).alias("unique_wishlisters")
        ]
        
        obt_final = obt.select(*final_columns)

        print("🧮 Adicionando métricas calculadas...")
        
        # Adicionando métricas calculadas
        obt_final = obt_final.withColumn(
            "conversion_rate", 
            when(col("total_wishlisted") > 0, 
                 col("total_purchases") / col("total_wishlisted")
            ).otherwise(0.0)
        ).withColumn(
            "review_participation_rate",
            when(col("total_purchases") > 0,
                 col("total_reviews") / col("total_purchases")
            ).otherwise(0.0)
        ).withColumn(
            "achievement_completion_rate",
            when(col("total_achievements_available") > 0,
                 col("total_achievements_unlocked") / col("total_achievements_available")
            ).otherwise(0.0)
        ).withColumn(
            "revenue_estimate",
            col("total_purchases") * col("game_price")
        ).withColumn(
            "popularity_score",
            (col("total_purchases") * 0.4) + 
            (col("avg_rating") * col("total_reviews") * 0.3) + 
            (col("total_wishlisted") * 0.2) + 
            (col("users_with_achievements") * 0.1)
        )

        print("🏷️ Adicionando categorias...")
        
        # Categorização de jogos
        obt_final = obt_final.withColumn(
            "sales_category",
            when(col("total_purchases") >= 1000, "High Sales")
            .when(col("total_purchases") >= 100, "Medium Sales")
            .when(col("total_purchases") > 0, "Low Sales")
            .otherwise("No Sales")
        ).withColumn(
            "rating_category",
            when(col("avg_rating") >= 4.5, "Excellent")
            .when(col("avg_rating") >= 4.0, "Very Good")
            .when(col("avg_rating") >= 3.5, "Good")
            .when(col("avg_rating") >= 3.0, "Average")
            .when(col("avg_rating") > 0, "Below Average")
            .otherwise("Not Rated")
        ).withColumn(
            "price_category",
            when(col("game_price") >= 60, "Premium")
            .when(col("game_price") >= 30, "Standard")
            .when(col("game_price") >= 10, "Budget")
            .when(col("game_price") > 0, "Indie")
            .otherwise("Free")
        )

        print("🏆 Criando rankings...")
        
        # Rankings
        from pyspark.sql.window import Window
        
        sales_window = Window.orderBy(col("total_purchases").desc())
        rating_window = Window.orderBy(col("avg_rating").desc(), col("total_reviews").desc())
        popularity_window = Window.orderBy(col("popularity_score").desc())
        
        obt_final = obt_final.withColumn(
            "sales_rank", 
            row_number().over(sales_window)
        ).withColumn(
            "rating_rank", 
            row_number().over(rating_window)
        ).withColumn(
            "popularity_rank", 
            row_number().over(popularity_window)
        )

        # Adicionando metadados
        from datetime import datetime
        current_timestamp = datetime.now()
        
        obt_final = obt_final.withColumn(
            "created_at", 
            lit(current_timestamp.strftime("%Y-%m-%d %H:%M:%S"))
        ).withColumn(
            "data_quality_score",
            when(col("game_title") != "", 1).otherwise(0) +
            when(col("game_description") != "", 1).otherwise(0) +
            when(col("game_price") > 0, 1).otherwise(0) +
            when(col("release_date").isNotNull(), 1).otherwise(0) +
            when(col("developer_name") != "Unknown", 1).otherwise(0)
        )

        print(f"✅ One Big Table criada com {obt_final.count():,} registros e {len(obt_final.columns)} colunas")
        
        return obt_final
        
    except Exception as e:
        print(f"❌ ERRO GERAL ao criar OBT: {str(e)}")
        import traceback
        traceback.print_exc()
        return None

# %% [markdown]
# ### Execução da Pipeline

# %%
silver_tables = carregar_tabelas_silver()
# Out:
# 📊 Carregando 14 tabelas da camada Silver...

# %% [markdown]
# ### Função para criar OBT

# %%
silver_tables = carregar_tabelas_silver()

if silver_tables:
    obt_games = criar_one_big_table(silver_tables)
    
    if obt_games is not None:
        # Cache para performance
        obt_games.cache()
        
        # Salvar OBT
        salvar_obt_gold(obt_games, "obt_games_master")
        
        # === ANÁLISES RESUMIDAS ===
        print("\n📊 ANÁLISES DA ONE BIG TABLE:")
        
        total_games = obt_games.count()
        games_with_sales = obt_games.filter(col("total_purchases") > 0).count()
        total_revenue = obt_games.agg(sum("total_purchases")).collect()[0][0] or 0
        avg_rating_all = obt_games.filter(col("avg_rating") > 0).agg(avg("avg_rating")).collect()[0][0] or 0
        
        print(f"🎮 Total de jogos: {total_games:,}")
        print(f"💰 Jogos com vendas: {games_with_sales:,} ({games_with_sales/total_games*100:.1f}%)")
        print(f"💵 Total de vendas: {total_revenue:,} unidades")
        print(f"⭐ Avaliação média: {avg_rating_all:.2f}")
        
        # Top 5 por categoria - verificando se colunas existem
        print("\n🏆 TOP 5 JOGOS POR VENDAS:")
        if "total_purchases" in obt_games.columns:
            obt_games.select("game_title", "total_purchases", "avg_rating")\
                .orderBy(col("total_purchases").desc())\
                .show(5, truncate=False)
        
        print("\n⭐ TOP 5 JOGOS POR AVALIAÇÃO:")
        if "total_reviews" in obt_games.columns and "avg_rating" in obt_games.columns:
            obt_games.filter(col("total_reviews") >= 3)\
                .select("game_title", "avg_rating", "total_reviews", "total_purchases")\
                .orderBy(col("avg_rating").desc(), col("total_reviews").desc())\
                .show(5, truncate=False)
        
        # Distribuição por categorias - verificando se existem
        if "sales_category" in obt_games.columns:
            print("\n📊 DISTRIBUIÇÃO POR CATEGORIA DE VENDAS:")
            obt_games.groupBy("sales_category")\
                .agg(count("*").alias("total_games"),
                     sum("total_purchases").alias("total_sales"))\
                .orderBy(col("total_sales").desc())\
                .show()
        
        if "rating_category" in obt_games.columns:
            print("\n📊 DISTRIBUIÇÃO POR CATEGORIA DE AVALIAÇÃO:")
            obt_games.groupBy("rating_category")\
                .agg(count("*").alias("total_games"),
                     avg("avg_rating").alias("avg_rating_category"))\
                .orderBy(col("avg_rating_category").desc())\
                .show()
        
        # Estatísticas finais
        print("\n📋 ESTATÍSTICAS GERAIS DA OBT:")
        print(f"   📊 Total de colunas: {len(obt_games.columns)}")
        print(f"   🎮 Jogos únicos: {obt_games.select('game_id').distinct().count():,}")
        
        # Verificar se developer_name existe antes de usar
        if "developer_name" in obt_games.columns:
            dev_count = obt_games.filter(col('developer_name') != 'Unknown').select('developer_name').distinct().count()
            print(f"   🏢 Desenvolvedores únicos: {dev_count:,}")
        
        # Limpeza
        obt_games.unpersist()
        
        print("\n🎉 PIPELINE CONCLUÍDO COM SUCESSO!")
        print("✅ One Big Table salva como: pipeline_gold.obt_games_master")
        
    else:
        print("❌ Falha na criação da OBT!")
else:
    print("❌ Nenhuma tabela Silver encontrada!")

print("\n🚀 Pipeline finalizada!")
# Out:
# 📊 Carregando 14 tabelas da camada Silver...
# 🏗️  Construindo One Big Table única...
# 📋 Tabelas disponíveis: ['achievement_unlocked', 'achievements', 'developers', 'dlcs', 'game_genders', 'game_platforms', 'game_tags', 'games', 'genders', 'platforms', 'purchases', 'reviews', 'tags', 'users']
# ✅ Tabela 'games' com 2 registros
# 📋 Colunas da tabela games: ['ID', 'TITLE', 'DEVELOPER_ID', 'NOME_ARQUIVO_BRONZE', 'DATA_HORA_SILVER']
# 📊 Criando agregações...
#     ✅ Métricas de vendas processadas
#     ✅ Métricas de avaliações processadas
#     ✅ Métricas de achievements processadas
#     ✅ Métricas de DLCs processadas
#     ✅ Informações de plataformas processadas
#     ✅ Informações de gêneros processadas
#     ✅ Informações de tags processadas
# 🔧 Montando One Big Table...
#     ✅ Join com developers
#     ✅ Join com purchases
#     ✅ Join com reviews
#     ✅ Join com achievements
#     ✅ Join com dlcs
#     ✅ Join com platforms
#     ✅ Join com genres
#     ✅ Join com tags
# ...

# %% [markdown]
# ## Verificação Final das Tabelas Gold Criadas

# %%
print("\n🔍 Verificando tabelas criadas na camada Gold:")
tabelas_gold = spark.sql("SHOW TABLES IN pipeline_gold").collect()

for tabela in tabelas_gold:
    nome_tabela = tabela['tableName']
    count_registros = spark.sql(f"SELECT COUNT(*) as total FROM pipeline_gold.{nome_tabela}").collect()[0]['total']
    print(f"   📊 {nome_tabela}: {count_registros:,} registros")

print("\n🎯 Pipeline Silver to Gold finalizado!")
print("🚀 A One Big Table está pronta para análises avançadas e dashboards!")
# Out:
# 🔍 Verificando tabelas criadas na camada Gold:
#    📊 games_rankings: 2 registros
#    📊 obt_comp_master: 2 registros
#    📊 obt_games_master: 2 registros
#    📊 resumo_executivo_games: 1 registros
#
# 🎯 Pipeline Silver to Gold finalizado!
# 🚀 A One Big Table está pronta para análises avançadas e dashboards!
